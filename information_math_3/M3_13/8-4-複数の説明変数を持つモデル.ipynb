# %% [markdown]
# # 情報数学Ⅲ 第13回

# %%
# 必要なデータファイルを取得
import requests

base_url = "https://raw.githubusercontent.com/logics-of-blue/book-python-stats-2nd/refs/heads/main/book-data/"
filenames = [
    "8-4-1-brand-1.csv",
    "8-4-2-brand-2.csv",
    "8-4-3-brand-3.csv"
]

for filename in filenames:
    url = base_url + filename
    print(f"Downloading {filename}...")
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
    else:
        print(f"Failed to download {filename}: {response.status_code}")
# Out:
# Downloading 8-4-1-brand-1.csv...
# Downloading 8-4-2-brand-2.csv...
# Downloading 8-4-3-brand-3.csv...

# %% [markdown]
# # 第8部　正規線形モデル
#
# ## 4章　複数の説明変数を持つモデル

# %% [markdown]
# ### 実装：分析の準備

# %%
# 数値計算に使うライブラリ
import numpy as np
import pandas as pd
from scipy import stats
# 表示桁数の設定
pd.set_option('display.precision', 3)
np.set_printoptions(precision=3)

# グラフを描画するライブラリ
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# 統計モデルを推定するライブラリ
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
# 表示設定(書籍本文のレイアウトと合わせるためであり、必須ではありません)
np.set_printoptions(linewidth=65)
pd.set_option('display.width', 65)

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 8, 4

# %%
# データの読み込み
brand_1 = pd.read_csv('8-4-1-brand-1.csv')
print(brand_1.head(n=3))
# Out:
#    sales brand  local_population
# 0  348.0     A             215.1
# 1  169.7     A             152.0
# 2  143.7     A             107.7

# %%
# ブランド
brand_1.brand.value_counts()
# Out:
# brand
# A    15
# B    15
# Name: count, dtype: int64

# %% [markdown]
# ### 実装：（悪い分析例）単純な平均値の比較

# %% [markdown]
# #### 平均値の比較

# %%
# ブランド別平均値の比較
print(brand_1.groupby('brand').mean())
# Out:
#          sales  local_population
# brand
# A      283.707           268.973
# B      403.927           437.933

# %%
# ブランドと売り上げの関係
sns.boxplot(x='brand', y='sales', data=brand_1, color='gray')
# Out:
# <Axes: xlabel='brand', ylabel='sales'>

# %% [markdown]
# #### 説明変数を1つだけ使ったモデル

# %%
lm_dame_1 = smf.ols('sales ~ brand', brand_1).fit()
lm_dame_1.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# 分散分析表
print(sm.stats.anova_lm(lm_dame_1, typ=1).round(3))
# Out:
#             df      sum_sq     mean_sq       F  PR(>F)
# brand      1.0  108396.363  108396.363  10.211   0.003
# Residual  28.0  297230.019   10615.358     NaN     NaN

# %% [markdown]
# ### 実装：回帰直線の切片の比較

# %%
lm_model_1 = smf.ols('sales ~ brand + local_population', 
                     data=brand_1).fit()
lm_model_1.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
sns.lmplot(x='local_population', y='sales', data=brand_1,
           col='brand',           
           scatter_kws = {'color': 'black'},
           line_kws    = {'color': 'black'},
           ci=None, height=4, aspect=1)

# %% [markdown]
# ### 実装：素朴な分散分析による検定

# %%
# 分散分析表
print(sm.stats.anova_lm(lm_model_1, typ=1).round(3))
# Out:
#                     df      sum_sq     mean_sq       F  PR(>F)
# brand              1.0  108396.363  108396.363  26.658     0.0
# local_population   1.0  187442.822  187442.822  46.098     0.0
# Residual          27.0  109787.197    4066.192     NaN     NaN

# %% [markdown]
# ### 実装：複数の説明変数がある場合の平方和の計算

# %% [markdown]
# #### 「Nullモデル」の作成

# %%
# Nullモデルの残差平方和
mod_null = smf.ols('sales ~ 1', brand_1).fit()
resid_sq_null = np.sum(mod_null.resid ** 2)
round(resid_sq_null, 3)
# Out:
# np.float64(405626.382)

# %% [markdown]
# #### 「Nullモデル」と「ブランドモデル」の比較

# %%
# ブランドだけを入れたモデルの残差平方和
resid_sq_brand = np.sum(lm_dame_1.resid ** 2)
round(resid_sq_brand, 3)
# Out:
# np.float64(297230.019)

# %%
round(resid_sq_null - resid_sq_brand, 3)
# Out:
# np.float64(108396.363)

# %%
print(sm.stats.anova_lm(lm_dame_1, typ=1).round(3))
# Out:
#             df      sum_sq     mean_sq       F  PR(>F)
# brand      1.0  108396.363  108396.363  10.211   0.003
# Residual  28.0  297230.019   10615.358     NaN     NaN

# %% [markdown]
# #### 「ブランドモデル」と「ブランド＋地域人口モデル」の比較

# %%
# ブランド+地域人口モデルの残差平方和
resid_sq_all = np.sum(lm_model_1.resid ** 2)
round(resid_sq_all, 3)
# Out:
# np.float64(109787.197)

# %%
round(resid_sq_brand - resid_sq_all, 3)
# Out:
# np.float64(187442.822)

# %%
print(sm.stats.anova_lm(lm_model_1, typ=1).round(3))
# Out:
#                     df      sum_sq     mean_sq       F  PR(>F)
# brand              1.0  108396.363  108396.363  26.658     0.0
# local_population   1.0  187442.822  187442.822  46.098     0.0
# Residual          27.0  109787.197    4066.192     NaN     NaN

# %% [markdown]
# ### 実装：Type II 検定

# %% [markdown]
# #### 調整平方和の計算

# %%
# 地域人口だけを入れたモデルの残差平方和
lm_model_pop = smf.ols('sales ~ local_population', 
                     data=brand_1).fit()
resid_sq_pop = np.sum(lm_model_pop.resid ** 2)
round(resid_sq_pop, 3)
# Out:
# np.float64(109936.322)

# %%
round(resid_sq_pop - resid_sq_all, 3)
# Out:
# np.float64(149.125)

# %% [markdown]
# #### Type II 検定の実行

# %%
print(sm.stats.anova_lm(lm_model_1, typ=2).round(3))
# Out:
#                       sum_sq    df       F  PR(>F)
# brand                149.125   1.0   0.037    0.85
# local_population  187442.822   1.0  46.098    0.00
# Residual          109787.197  27.0     NaN     NaN

# %%
# 2つのモデルの比較
np.round(lm_model_1.compare_f_test(lm_model_pop), 3)
# Out:
# array([0.037, 0.85 , 1.   ])

# %% [markdown]
# ### 実装：新たなデータの読み込み

# %%
# データの読み込み
brand_2 = pd.read_csv('8-4-2-brand-2.csv')
print(brand_2.head(n=3))
# Out:
#    sales brand  local_population
# 0  385.8     A             265.6
# 1  473.0     A             386.1
# 2  451.6     A             522.7

# %% [markdown]
# ### 実装：（悪い分析例）交互作用を入れないでモデルを作る

# %%
lm_dame_2 = smf.ols('sales ~ brand + local_population', 
                    brand_2).fit()
print(sm.stats.anova_lm(lm_dame_2, typ=2).round(3))
# Out:
#                       sum_sq    df        F  PR(>F)
# brand                 34.275   1.0    0.007   0.933
# local_population  484195.711   1.0  100.427   0.000
# Residual          226604.693  47.0      NaN     NaN

# %%
sns.lmplot(x='local_population', y='sales', data=brand_2,
           col='brand',           
           scatter_kws = {'color': 'black'},
           line_kws    = {'color': 'black'},
           ci=None, height=4, aspect=1)

# %% [markdown]
# ### 実装：交互作用を入れたモデルの作成

# %%
# 交互作用を入れたモデルを作る
lm_model_2 = smf.ols('sales ~ brand * local_population', 
                     data=brand_2).fit()
lm_model_2.params
# Out:
# Intercept                      254.524
# brand[T.B]                    -182.924
# local_population                 0.486
# brand[T.B]:local_population      0.508
# dtype: float64

# %%
# 下記のように実装しても同じ
lm_model_2_2 = smf.ols('sales ~ brand + local_population + brand:local_population', 
                       data=brand_2).fit()
lm_model_2_2.params
# Out:
# Intercept                      254.524
# brand[T.B]                    -182.924
# local_population                 0.486
# brand[T.B]:local_population      0.508
# dtype: float64

# %% [markdown]
# ### 実装：Type III 検定

# %% [markdown]
# #### Type II 検定の実行

# %%
# type II 検定
print(sm.stats.anova_lm(lm_model_2, typ=2).round(3))
# Out:
#                             sum_sq    df        F  PR(>F)
# brand                       34.275   1.0    0.009   0.924
# local_population        484195.711   1.0  130.689   0.000
# brand:local_population   56176.608   1.0   15.163   0.000
# Residual                170428.085  46.0      NaN     NaN

# %% [markdown]
# #### 調整平方和の計算

# %%
# フルモデルの残差平方和
resid_sq_full = np.sum(lm_model_2.resid ** 2)
round(resid_sq_full, 3)
# Out:
# np.float64(170428.085)

# %%
mod_non_brand = smf.ols(
    'sales ~ local_population + brand:local_population', 
    data=brand_2).fit()
resid_sq_non_brand = np.sum(mod_non_brand.resid ** 2)
round(resid_sq_non_brand, 3)
# Out:
# np.float64(220745.808)

# %%
# 調整平方和
round(resid_sq_non_brand - resid_sq_full, 3)
# Out:
# np.float64(50317.723)

# %% [markdown]
# #### Type III 検定の実行

# %%
# type III 検定
print(sm.stats.anova_lm(lm_model_2, typ=3).round(3))
# Out:
#                             sum_sq    df       F  PR(>F)
# Intercept               195523.067   1.0  52.773   0.000
# brand                    50317.723   1.0  13.581   0.001
# local_population        100639.827   1.0  27.164   0.000
# brand:local_population   56176.608   1.0  15.163   0.000
# Residual                170428.085  46.0     NaN     NaN

# %% [markdown]
# ### 実装：AICによる変数選択

# %%
print('交互作用なしモデルのAIC', round(lm_dame_2.aic, 3))
print('交互作用ありモデルのAIC', round(lm_model_2.aic, 3))
# Out:
# 交互作用なしモデルのAIC 568.841
# 交互作用ありモデルのAIC 556.596

# %% [markdown]
# ### 実装：交互作用項の解釈

# %% [markdown]
# #### 係数の取得

# %%
lm_model_2.params
# Out:
# Intercept                      254.524
# brand[T.B]                    -182.924
# local_population                 0.486
# brand[T.B]:local_population      0.508
# dtype: float64

# %%
# 係数を個別に取得
Intercept = lm_model_2.params[0]
coef_brand_B = lm_model_2.params[1]
coef_local_population = lm_model_2.params[2]
Interaction = lm_model_2.params[3]
# Out:
# /var/folders/zc/5fcnnpks6jz06b0n0_b6ngjm0000gn/T/ipykernel_20827/2628460345.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Intercept = lm_model_2.params[0]
# /var/folders/zc/5fcnnpks6jz06b0n0_b6ngjm0000gn/T/ipykernel_20827/2628460345.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coef_brand_B = lm_model_2.params[1]
# /var/folders/zc/5fcnnpks6jz06b0n0_b6ngjm0000gn/T/ipykernel_20827/2628460345.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coef_local_population = lm_model_2.params[2]
# /var/folders/zc/5fcnnpks6jz06b0n0_b6ngjm0000gn/T/ipykernel_20827/2628460345.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Interaction = lm_model_2.params[3]

# %% [markdown]
# #### local_population=0のときの予測値

# %%
# brand=Aで、かつ、local_population=0
lm_model_2.predict(
    pd.DataFrame({'brand':['A'], 'local_population':[0]}))
# Out:
# 0    254.524
# dtype: float64

# %%
pred_1 = Intercept
round(pred_1, 3)
# Out:
# np.float64(254.524)

# %%
# brand=Bで、かつ、local_population=0
lm_model_2.predict(
    pd.DataFrame({'brand':['B'], 'local_population':[0]}))
# Out:
# 0    71.599
# dtype: float64

# %%
pred_2 = Intercept + coef_brand_B
round(pred_2, 3)
# Out:
# np.float64(71.599)

# %% [markdown]
# #### local_population=150のときの予測値

# %%
# brand=Aで、かつ、local_population=150
lm_model_2.predict(
    pd.DataFrame({'brand':['A'], 'local_population':[150]}))
# Out:
# 0    327.413
# dtype: float64

# %%
pred_3 = Intercept + coef_local_population * 150
round(pred_3, 3)
# Out:
# np.float64(327.413)

# %%
# brand=Bで、かつ、local_population=150
lm_model_2.predict(
    pd.DataFrame({'brand':['B'], 'local_population':[150]}))
# Out:
# 0    220.679
# dtype: float64

# %%
pred_4 = Intercept + coef_brand_B + \
   (coef_local_population + Interaction) * 150
round(pred_4, 3)
# Out:
# np.float64(220.679)

# %% [markdown]
# ### 実装：formula構文の機能

# %%
# データの読み込み
brand_3 = pd.read_csv('8-4-3-brand-3.csv')
print(brand_3.head(n=3))
# Out:
#    sales  brand  local_population
# 0  385.8    0.0             265.6
# 1  473.0    0.0             386.1
# 2  451.6    0.0             522.7

# %%
# 参考：もとのデータ(書籍には載っていないコードです)
brand_2.brand.value_counts()
# Out:
# brand
# A    25
# B    25
# Name: count, dtype: int64

# %%
# ブランドを数値で表現したデータ
brand_3.brand.value_counts()
# Out:
# brand
# 0.0     25
# 99.0    25
# Name: count, dtype: int64

# %%
# ブランドが数値扱いになっているので係数が変わる
lm_model_3 = smf.ols(
    'sales ~ brand * local_population', 
    data=brand_3).fit()
lm_model_3.params
# Out:
# Intercept                 254.524
# brand                      -1.848
# local_population            0.486
# brand:local_population      0.005
# dtype: float64

# %%
# ブランドをカテゴリーとして扱う
lm_model_3_2 = smf.ols(
    'sales ~ C(brand) * local_population', 
    data=brand_3).fit()
lm_model_3_2.params
# Out:
# Intercept                            254.524
# C(brand)[T.99.0]                    -182.924
# local_population                       0.486
# C(brand)[T.99.0]:local_population      0.508
# dtype: float64

# %%
# 参考：パラメータの一覧(書籍には載っていないコードです)
lm_model_2.params
# Out:
# Intercept                      254.524
# brand[T.B]                    -182.924
# local_population                 0.486
# brand[T.B]:local_population      0.508
# dtype: float64

# %% [markdown]
# ### 実装：デザイン行列

# %%
from patsy import dmatrix
dmatrix('brand * local_population', brand_2)
# Out:
# DesignMatrix with shape (50, 4)
#   Intercept  brand[T.B]  local_population  brand[T.B]:local_population
#           1           0             265.6                          0.0
#           1           0             386.1                          0.0
#           1           0             522.7                          0.0
#           1           0             530.5                          0.0
#           1           0             397.8                          0.0
#           1           0             142.3                          0.0
#           1           0             398.6                          0.0
#           1           0             222.7                          0.0
#           1           0             466.3                          0.0
#           1           0             547.3                          0.0
#           1           0             357.4                          0.0
#           1           0             401.8                          0.0
#           1           0             132.5                          0.0
#           1           0             370.0                          0.0
#           1           0             164.6                          0.0
#           1           0             407.3                          0.0
#           1           0             281.8                          0.0
#           1           0             483.9                          0.0
#           1           0             124.3                          0.0
#           1           0             154.9                          0.0
#           1           0             442.0                          0.0
#           1           0             357.3                          0.0
#           1           0             385.8                          0.0
#           1           0             521.9                          0.0
#           1           0             343.9                          0.0
#           1           1             505.1                        505.1
#           1           1             355.1                        355.1
#           1           1             563.4                        563.4
#           1           1             433.5                        433.5
#           1           1             174.4                        174.4
#   [20 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'brand' (column 1)
#     'local_population' (column 2)
#     'brand:local_population' (column 3)
#   (to view full data, use np.asarray(this_obj))
