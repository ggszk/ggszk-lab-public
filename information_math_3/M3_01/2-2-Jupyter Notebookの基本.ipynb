# %% [markdown]
# # 第2部　PythonとJupyter Notebookの基本
#
# ## 2章　Jupyter Notebookの基本

# %% [markdown]
# ### 計算の実行方法

# %%
1

# %% [markdown]
# ### Markdownの使い方

# %% [markdown]
# # 大きな表題
# ## 少し小さな表題
# -----------------
# - 箇条書き
# - 箇条書き
# -----------------
# 1. 箇条書き
# 1. 箇条書き
