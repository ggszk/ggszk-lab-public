# %% [markdown]
# # データベース演習 第6回
#
# ### 🔍 利用方法
#
# - このノートブックは**閲覧専用**です。
#   自分のGoogleドライブにコピーを作成してから編集してください。
#
#   1. メニューの「**ファイル → ドライブにコピーを保存**」を選ぶ
#   2. コピーしたノートブックの**ファイル名（左上の"xxxx"）を学籍番号に変更**してください（提出時の識別のため）
#
# ---
#
# ### 🔧 提出手順
#
# 1. Google Colab の右上にある「**共有**」ボタンをクリック
# 2. 「**一般的なアクセス**」の設定を「**リンクを知っている全員**」に変更
# 3. アクセス権を「**閲覧者**」に設定（⚠️「編集者」にしないこと！）
# 4. 表示されるURLをコピー
# 5. WebClassの提出フォームに、その**URLを貼り付けて提出**
#
# ---
#
# ### 💡 補足・注意点
#
# - 「編集者」ではなく「閲覧者」に設定してください。
#   → 教員が間違ってファイルを上書きしてしまうのを防ぐためです。
# - **提出したリンクを自分でも一度開いてみて、ちゃんと共有されているかを確認**してください。

# %% [markdown]
# ## 使用するデータベースのダウンロード
#
# * 次のセルで私のgithubリポジトリにあるSQLite3のデータベースをダウンロードしています
#   * weblogデータベース（テーブル3個のみ）
# * ダウンロードは，（私の大学の環境では）10秒以内に完了します
# * Colabのランタイムが切り替わると，その度にダウンロードする必要があります

# %%
# SQLiteファイルをダウンロード

# weblogデータベース（テーブル3個のみ）
# !curl -sLO https://raw.githubusercontent.com/ggszk/ggszk-lab-public/refs/heads/main/db/weblog.sqlite3

# %% [markdown]
# ## jupysqlの環境設定

# %%
# Colabではjupysqlのインストールが必要
import sys
if 'google.colab' in sys.modules:
    # %pip install -q jupysql

# %%
# jupysqlの読み込み
# %load_ext sql

# %%
# weblogデータベースに接続する
# %sql sqlite:///weblog.sqlite3

# %% [markdown]
# ### weblogデータベースに含まれるテーブルの確認

# %%
# %%sql
# SELECT * FROM sqlite_master;

# %% [markdown]
# ## 例題：SQL
#
# customersテーブルに対して，以下のようなSQL文を作成し，実行せよ（行数が少し多いため，(3)-(5)は指定された数に結果行数を制限すること）
#
# * **まずは資料を見ずに，自力でSQLを書いてみよう**
# * SQL文は問題文の次のセルに記述せよ（`%%sql`は最初から入れている）
# * 書けたら，講義資料の「例題の解答」スライドで答え合わせをする

# %% [markdown]
# (1) customersテーブルの全行数を数えるSQL文

# %%
# %%sql

# %% [markdown]
# (2) customer_genderがFである行数を数えるSQL文（なお，Fは女性を表す）

# %%
# %%sql

# %% [markdown]
# (3) customer_ageが30より大きい行の，customer_idとcustomer_ageを求めるSQL文(結果の上限を10行に制限せよ)

# %%
# %%sql

# %% [markdown]
# (4) customer_ageが26または19である行の，customer_idとcustomer_ageを求めるSQL文(結果の上限を10行に制限せよ)

# %%
# %%sql

# %% [markdown]
# (5) customer_ageが若い順に，customer_idとcustomer_ageを求めるSQL文(結果の上限を10行に制限せよ)

# %%
# %%sql

# %% [markdown]
# # 演習：サンプルデータのSQLによる検索
#
# * itemsテーブルに対して，以下のようなSQL文を作成せよ（行数が少し多いため，(3)-(5)は指定された数に結果行数を制限すること）
# * SQL文は問題文の次のセルに記述せよ（%%sqlは最初から入れている）
# * SQL文の実行結果は，提出時に残しておくこと

# %% [markdown]
# (1) itemsテーブルの全行数を数えるSQL文

# %%
# %%sql

# %% [markdown]
# (2) item_priceが10000より大きい行数を数えるSQL文

# %%
# %%sql

# %% [markdown]
# (3) item_priceが2000より小さい行の，item_idとitem_priceを求めるSQL文(結果の上限を10行に制限せよ)

# %%
# %%sql

# %% [markdown]
# (4) shop_idが1または2である行の，item_idとshop_idを求めるSQL文(結果の上限を10行に制限せよ)

# %%
# %%sql

# %% [markdown]
# (5) item_priceが大きい順に，item_idとitem_priceを求めるSQL文(結果の上限を10行に制限せよ)

# %%
# %%sql
